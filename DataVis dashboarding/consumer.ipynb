# %%
from kafka import KafkaConsumer
import json
from json import loads

TOPIC_NAME = "sinkTopic"
consumer = KafkaConsumer(
    'IotData',
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     group_id='IotData',
     value_deserializer=lambda x: loads(x.decode('utf-8')))
print("starting the consuming data")
for msg in consumer:
    msg=msg.value
    print(msg)
    #print("IOT sensor's data = {}".format(json.loads(msg.value)))
# Out:
# starting the consuming data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [30], line 14
#       6 consumer = KafkaConsumer(
#       7     'IotData',
#       8      bootstrap_servers=['localhost:9092'],
#    (...)
#      11      group_id='IotData',
#      12      value_deserializer=lambda x: loads(x.decode('utf-8')))
#      13 print("starting the consuming data")
# ---> 14 for msg in consumer:
#      15     msg=msg.value
#      16     print(msg)
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:675, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     665 def _poll_once(self, timeout_ms, max_records, update_offsets=True):
#     666     """Do one round of polling. In addition to checking for new data, this does
#     667     any needed heart-beating, auto-commits, and offset updates.
#     668
#    (...)
#     673         dict: Map of topic to list of records (may be empty).
#     674     """
# --> 675     self._coordinator.poll()
#     677     # Fetch positions if we have partitions we're subscribed to that we
#     678     # don't know the offset for
#     679     if not self._subscription.has_all_fetch_positions():
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/coordinator/consumer.py:289, in ConsumerCoordinator.poll(self)
#     286             metadata_update = self._client.cluster.request_update()
#     287             self._client.poll(future=metadata_update)
# --> 289         self.ensure_active_group()
#     291     self.poll_heartbeat()
#     293 self._maybe_auto_commit_offsets_async()
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/coordinator/base.py:407, in BaseCoordinator.ensure_active_group(self)
#     404 else:
#     405     future = self.join_future
# --> 407 self._client.poll(future=future)
#     409 if future.succeeded():
#     410     self._on_join_complete(self._generation.generation_id,
#     411                            self._generation.member_id,
#     412                            self._generation.protocol,
#     413                            future.value)
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:

# %%
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads

client = MongoClient('localhost:27017')
collection = client.numtest.numtest

consumer = KafkaConsumer(
    'IotData',
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
    # group_id='IotData',
     value_deserializer=lambda x: loads(x.decode('utf-8')))



for message in consumer:
    message1 = message.value
    #collection.insert_one(message)
    print(message1)
    #print('{} added to {}'.format(message, collection))
# Out:
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '106', 'P': '16', 'K': '54', 'temperature': '28.96017885', 'humidity': '91.69532178', 'ph': '6.585872508', 'rainfall': '24.7458198', 'label': 'muskmelon'}
# {'N': '10', 'P': '140', 'K': '197', 'temperature': '22.16939473', 'humidity': '90.27185592', 'ph': '6.229498836', 'rainfall': '124.4683112', 'label': 'apple'}
# {'N': '31', 'P': '26', 'K': '9', 'temperature': '11.69894639', 'humidity': '93.25638873', 'ph': '7.566165721', 'rainfall': '103.2005992', 'label': 'orange'}
# {'N': '39', 'P': '64', 'K': '53', 'temperature': '23.012401800000006', 'humidity': '91.07355541', 'ph': '6.598860305', 'rainfall': '208.3357976', 'label': 'papaya'}
# {'N': '19', 'P': '26', 'K': '29', 'temperature': '26.93141945', 'humidity': '98.80313612', 'ph': '5.67154928', 'rainfall': '166.5712879', 'label': 'coconut'}
# {'N': '120', 'P': '60', 'K': '15', 'temperature': '22.31871914', 'humidity': '83.86129998', 'ph': '7.288377241', 'rainfall': '65.35747011', 'label': 'cotton'}
# {'N': '84', 'P': '38', 'K': '43', 'temperature': '26.57421679', 'humidity': '73.81994896', 'ph': '7.26158085', 'rainfall': '159.3223075', 'label': 'jute'}
# {'N': '104', 'P': '18', 'K': '30', 'temperature': '23.60301571', 'humidity': '60.39647474', 'ph': '6.779832611000002', 'rainfall': '140.9370415', 'label': 'coffee'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '106', 'P': '16', 'K': '54', 'temperature': '28.96017885', 'humidity': '91.69532178', 'ph': '6.585872508', 'rainfall': '24.7458198', 'label': 'muskmelon'}
# {'N': '10', 'P': '140', 'K': '197', 'temperature': '22.16939473', 'humidity': '90.27185592', 'ph': '6.229498836', 'rainfall': '124.4683112', 'label': 'apple'}
# {'N': '31', 'P': '26', 'K': '9', 'temperature': '11.69894639', 'humidity': '93.25638873', 'ph': '7.566165721', 'rainfall': '103.2005992', 'label': 'orange'}
# {'N': '39', 'P': '64', 'K': '53', 'temperature': '23.012401800000006', 'humidity': '91.07355541', 'ph': '6.598860305', 'rainfall': '208.3357976', 'label': 'papaya'}
# {'N': '19', 'P': '26', 'K': '29', 'temperature': '26.93141945', 'humidity': '98.80313612', 'ph': '5.67154928', 'rainfall': '166.5712879', 'label': 'coconut'}
# {'N': '120', 'P': '60', 'K': '15', 'temperature': '22.31871914', 'humidity': '83.86129998', 'ph': '7.288377241', 'rainfall': '65.35747011', 'label': 'cotton'}
# {'N': '84', 'P': '38', 'K': '43', 'temperature': '26.57421679', 'humidity': '73.81994896', 'ph': '7.26158085', 'rainfall': '159.3223075', 'label': 'jute'}
# {'N': '104', 'P': '18', 'K': '30', 'temperature': '23.60301571', 'humidity': '60.39647474', 'ph': '6.779832611000002', 'rainfall': '140.9370415', 'label': 'coffee'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '106', 'P': '16', 'K': '54', 'temperature': '28.96017885', 'humidity': '91.69532178', 'ph': '6.585872508', 'rainfall': '24.7458198', 'label': 'muskmelon'}
# {'N': '10', 'P': '140', 'K': '197', 'temperature': '22.16939473', 'humidity': '90.27185592', 'ph': '6.229498836', 'rainfall': '124.4683112', 'label': 'apple'}
# {'N': '31', 'P': '26', 'K': '9', 'temperature': '11.69894639', 'humidity': '93.25638873', 'ph': '7.566165721', 'rainfall': '103.2005992', 'label': 'orange'}
# {'N': '39', 'P': '64', 'K': '53', 'temperature': '23.012401800000006', 'humidity': '91.07355541', 'ph': '6.598860305', 'rainfall': '208.3357976', 'label': 'papaya'}
# {'N': '19', 'P': '26', 'K': '29', 'temperature': '26.93141945', 'humidity': '98.80313612', 'ph': '5.67154928', 'rainfall': '166.5712879', 'label': 'coconut'}
# {'N': '120', 'P': '60', 'K': '15', 'temperature': '22.31871914', 'humidity': '83.86129998', 'ph': '7.288377241', 'rainfall': '65.35747011', 'label': 'cotton'}
# {'N': '84', 'P': '38', 'K': '43', 'temperature': '26.57421679', 'humidity': '73.81994896', 'ph': '7.26158085', 'rainfall': '159.3223075', 'label': 'jute'}
# {'N': '104', 'P': '18', 'K': '30', 'temperature': '23.60301571', 'humidity': '60.39647474', 'ph': '6.779832611000002', 'rainfall': '140.9370415', 'label': 'coffee'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '106', 'P': '16', 'K': '54', 'temperature': '28.96017885', 'humidity': '91.69532178', 'ph': '6.585872508', 'rainfall': '24.7458198', 'label': 'muskmelon'}
# {'N': '10', 'P': '140', 'K': '197', 'temperature': '22.16939473', 'humidity': '90.27185592', 'ph': '6.229498836', 'rainfall': '124.4683112', 'label': 'apple'}
# {'N': '31', 'P': '26', 'K': '9', 'temperature': '11.69894639', 'humidity': '93.25638873', 'ph': '7.566165721', 'rainfall': '103.2005992', 'label': 'orange'}
# {'N': '39', 'P': '64', 'K': '53', 'temperature': '23.012401800000006', 'humidity': '91.07355541', 'ph': '6.598860305', 'rainfall': '208.3357976', 'label': 'papaya'}
# {'N': '19', 'P': '26', 'K': '29', 'temperature': '26.93141945', 'humidity': '98.80313612', 'ph': '5.67154928', 'rainfall': '166.5712879', 'label': 'coconut'}
# {'N': '120', 'P': '60', 'K': '15', 'temperature': '22.31871914', 'humidity': '83.86129998', 'ph': '7.288377241', 'rainfall': '65.35747011', 'label': 'cotton'}
# {'N': '84', 'P': '38', 'K': '43', 'temperature': '26.57421679', 'humidity': '73.81994896', 'ph': '7.26158085', 'rainfall': '159.3223075', 'label': 'jute'}
# {'N': '104', 'P': '18', 'K': '30', 'temperature': '23.60301571', 'humidity': '60.39647474', 'ph': '6.779832611000002', 'rainfall': '140.9370415', 'label': 'coffee'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '106', 'P': '16', 'K': '54', 'temperature': '28.96017885', 'humidity': '91.69532178', 'ph': '6.585872508', 'rainfall': '24.7458198', 'label': 'muskmelon'}
# {'N': '10', 'P': '140', 'K': '197', 'temperature': '22.16939473', 'humidity': '90.27185592', 'ph': '6.229498836', 'rainfall': '124.4683112', 'label': 'apple'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '106', 'P': '16', 'K': '54', 'temperature': '28.96017885', 'humidity': '91.69532178', 'ph': '6.585872508', 'rainfall': '24.7458198', 'label': 'muskmelon'}
# {'N': '10', 'P': '140', 'K': '197', 'temperature': '22.16939473', 'humidity': '90.27185592', 'ph': '6.229498836', 'rainfall': '124.4683112', 'label': 'apple'}
# {'N': '31', 'P': '26', 'K': '9', 'temperature': '11.69894639', 'humidity': '93.25638873', 'ph': '7.566165721', 'rainfall': '103.2005992', 'label': 'orange'}
# {'N': '39', 'P': '64', 'K': '53', 'temperature': '23.012401800000006', 'humidity': '91.07355541', 'ph': '6.598860305', 'rainfall': '208.3357976', 'label': 'papaya'}
# {'N': '19', 'P': '26', 'K': '29', 'temperature': '26.93141945', 'humidity': '98.80313612', 'ph': '5.67154928', 'rainfall': '166.5712879', 'label': 'coconut'}
# {'N': '120', 'P': '60', 'K': '15', 'temperature': '22.31871914', 'humidity': '83.86129998', 'ph': '7.288377241', 'rainfall': '65.35747011', 'label': 'cotton'}
# {'N': '84', 'P': '38', 'K': '43', 'temperature': '26.57421679', 'humidity': '73.81994896', 'ph': '7.26158085', 'rainfall': '159.3223075', 'label': 'jute'}
# {'N': '104', 'P': '18', 'K': '30', 'temperature': '23.60301571', 'humidity': '60.39647474', 'ph': '6.779832611000002', 'rainfall': '140.9370415', 'label': 'coffee'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '106', 'P': '16', 'K': '54', 'temperature': '28.96017885', 'humidity': '91.69532178', 'ph': '6.585872508', 'rainfall': '24.7458198', 'label': 'muskmelon'}
# {'N': '10', 'P': '140', 'K': '197', 'temperature': '22.16939473', 'humidity': '90.27185592', 'ph': '6.229498836', 'rainfall': '124.4683112', 'label': 'apple'}
# {'N': '31', 'P': '26', 'K': '9', 'temperature': '11.69894639', 'humidity': '93.25638873', 'ph': '7.566165721', 'rainfall': '103.2005992', 'label': 'orange'}
# {'N': '39', 'P': '64', 'K': '53', 'temperature': '23.012401800000006', 'humidity': '91.07355541', 'ph': '6.598860305', 'rainfall': '208.3357976', 'label': 'papaya'}
# {'N': '19', 'P': '26', 'K': '29', 'temperature': '26.93141945', 'humidity': '98.80313612', 'ph': '5.67154928', 'rainfall': '166.5712879', 'label': 'coconut'}
# {'N': '120', 'P': '60', 'K': '15', 'temperature': '22.31871914', 'humidity': '83.86129998', 'ph': '7.288377241', 'rainfall': '65.35747011', 'label': 'cotton'}
# {'N': '84', 'P': '38', 'K': '43', 'temperature': '26.57421679', 'humidity': '73.81994896', 'ph': '7.26158085', 'rainfall': '159.3223075', 'label': 'jute'}
# {'N': '104', 'P': '18', 'K': '30', 'temperature': '23.60301571', 'humidity': '60.39647474', 'ph': '6.779832611000002', 'rainfall': '140.9370415', 'label': 'coffee'}
# {'N': '65', 'P': '37', 'K': '40', 'temperature': '23.35905428', 'humidity': '83.59512273', 'ph': '5.333322606', 'rainfall': '188.413665', 'label': 'rice'}
# {'N': '83', 'P': '57', 'K': '19', 'temperature': '25.73044432', 'humidity': '70.74739256', 'ph': '6.877869005', 'rainfall': '98.73771338', 'label': 'maize'}
# {'N': '49', 'P': '69', 'K': '82', 'temperature': '18.31561493', 'humidity': '15.36143547', 'ph': '7.26311855', 'rainfall': '81.78710463', 'label': 'chickpea'}
# {'N': '22', 'P': '60', 'K': '24', 'temperature': '18.78226261', 'humidity': '20.24768314', 'ph': '5.630664753', 'rainfall': '104.2570723', 'label': 'kidneybeans'}
# {'N': '33', 'P': '61', 'K': '24', 'temperature': '20.04611791', 'humidity': '48.93905624', 'ph': '4.567446499', 'rainfall': '122.4564203', 'label': 'pigeonpeas'}
# {'N': '16', 'P': '51', 'K': '21', 'temperature': '31.01963639', 'humidity': '49.97675220000001', 'ph': '3.532008668', 'rainfall': '32.81296548', 'label': 'mothbeans'}
# {'N': '25', 'P': '48', 'K': '21', 'temperature': '28.438097', 'humidity': '83.48991368', 'ph': '6.267684328', 'rainfall': '52.55469976', 'label': 'mungbean'}
# {'N': '38', 'P': '62', 'K': '25', 'temperature': '32.7477393', 'humidity': '67.77954584', 'ph': '7.453975408', 'rainfall': '63.37784443', 'label': 'blackgram'}
# {'N': '33', 'P': '77', 'K': '15', 'temperature': '23.89736406', 'humidity': '66.32102048', 'ph': '7.802212437', 'rainfall': '40.74536757', 'label': 'lentil'}
# {'N': '8', 'P': '28', 'K': '37', 'temperature': '23.88404783', 'humidity': '86.20613842', 'ph': '6.082571701', 'rainfall': '108.3121789', 'label': 'pomegranate'}
# {'N': '117', 'P': '81', 'K': '53', 'temperature': '29.50704598', 'humidity': '78.20585613', 'ph': '5.507641777999999', 'rainfall': '98.12565829', 'label': 'banana'}
# {'N': '18', 'P': '26', 'K': '31', 'temperature': '32.611261400000004', 'humidity': '47.74916499', 'ph': '5.418475257000001', 'rainfall': '91.10190759', 'label': 'mango'}
# {'N': '35', 'P': '134', 'K': '204', 'temperature': '9.949929082', 'humidity': '82.55138983', 'ph': '5.841138354', 'rainfall': '66.00817551', 'label': 'grapes'}
# {'N': '120', 'P': '24', 'K': '47', 'temperature': '26.98603693', 'humidity': '89.4138489', 'ph': '6.260838965', 'rainfall': '58.54876687', 'label': 'watermelon'}
# {'N': '106', 'P': '16', 'K': '54', 'temperature': '28.96017885', 'humidity': '91.69532178', 'ph': '6.585872508', 'rainfall': '24.7458198', 'label': 'muskmelon'}
# {'N': '10', 'P': '140', 'K': '197', 'temperature': '22.16939473', 'humidity': '90.27185592', 'ph': '6.229498836', 'rainfall': '124.4683112', 'label': 'apple'}
# {'N': '31', 'P': '26', 'K': '9', 'temperature': '11.69894639', 'humidity': '93.25638873', 'ph': '7.566165721', 'rainfall': '103.2005992', 'label': 'orange'}
# {'N': '39', 'P': '64', 'K': '53', 'temperature': '23.012401800000006', 'humidity': '91.07355541', 'ph': '6.598860305', 'rainfall': '208.3357976', 'label': 'papaya'}
# {'N': '19', 'P': '26', 'K': '29', 'temperature': '26.93141945', 'humidity': '98.80313612', 'ph': '5.67154928', 'rainfall': '166.5712879', 'label': 'coconut'}
# {'N': '120', 'P': '60', 'K': '15', 'temperature': '22.31871914', 'humidity': '83.86129998', 'ph': '7.288377241', 'rainfall': '65.35747011', 'label': 'cotton'}
# {'N': '84', 'P': '38', 'K': '43', 'temperature': '26.57421679', 'humidity': '73.81994896', 'ph': '7.26158085', 'rainfall': '159.3223075', 'label': 'jute'}
# {'N': '104', 'P': '18', 'K': '30', 'temperature': '23.60301571', 'humidity': '60.39647474', 'ph': '6.779832611000002', 'rainfall': '140.9370415', 'label': 'coffee'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [31], line 18
#       6 collection = client.numtest.numtest
#       8 consumer = KafkaConsumer(
#       9     'IotData',
#      10      bootstrap_servers=['localhost:9092'],
#    (...)
#      13     # group_id='IotData',
#      14      value_deserializer=lambda x: loads(x.decode('utf-8')))
# ---> 18 for message in consumer:
#      19     message1 = message.value
#      20     #collection.insert_one(message)
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:

# %%
print(collection)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')
